# %%
from tabulate import tabulate
from datetime import datetime
from openpyxl import load_workbook
from pprint import pprint
import os
from simple_smartsheet import Smartsheet
from simple_smartsheet.models import Sheet, Column, Row, Cell
import pandas as pd

# %%
from players import *

# %%
def get_indexes_from_xl_file():
	wb = load_workbook(filename = 'Handicap Index Course Handicap Report.xlsx')
	# print(wb)
	ws = wb['Sheet1']
	# print(ws)

	#Retrieve the player's indexes, compute handicaps
	for i in range(2, 21):
		# print(i)
		golfer_name = (ws.cell(row=i, column=3).value)
		# print(golfer_name)
		h_i = (float(ws.cell(row=i, column=4).value))


		#Update handicap info in Player Class, set playing to no.
		for player in player_list:
			if golfer_name == player.ghin_name:
				player.h_i = h_i
				player.class_tpc_white_70()
				player.class_tpc_white_72()
				player.class_cwv_white_71()
				player.playing = False
				# print (f" {golfer_name}, hi: {player.h_i}, tpc 70: {player.handicap_tpc_70}, tpc 72: {player.handicap_tpc_72} cwv: {player.handicap_cwv_71}, status = {player.playing}")

# %%
def update_player_status(day_of_play):
	TOKEN = '0b2269ovtwyvi1bmbqm15c2kg9'
	smartsheet = Smartsheet(TOKEN)
	# id=1798700143011716	'Jack Sign-Up'
	sheet = smartsheet.sheets.get(id=1798700143011716)

	#create list of players for specific date
	monday_list = []
	wednesday_list = []
	friday_list = [] 
	
	for row in sheet.rows:
	    player = row.get_cell("Player").value
	    monday_play = row.get_cell("Mon?").value
	    if monday_play: monday_list.append(player)

	    wednesday_play = row.get_cell("Wed?").value
	    if wednesday_play: wednesday_list.append(player)

	    friday_play = row.get_cell("Fri?").value
	    if friday_play:
	    	# print (f"{k}. {player} on Friday")
	    	# k += 1
	    	friday_list.append(player)	

	if day_of_play == 'M' or day_of_play == 'm':
		for player in player_list:
			if player.signup_name in monday_list:
				# print(f"{i}. {player.signup_name}")
				# i += 1
				player.playing = True

	elif day_of_play == 'W' or day_of_play == 'w':
		i = 1
		for player in player_list:
			if player.signup_name in wednesday_list:
				# print(f"{i:02}. {player.signup_name}")
				# i += 1
				player.playing = True

	elif day_of_play == 'F' or day_of_play == 'f':
		i = 1
		for player in player_list:
			if player.signup_name in friday_list:
				# print(f"{i}. {player.signup_name}")
				# i += 1
				player.playing = True
	
	else: print('Bad choice of Day')

# %%
def print_results_new(tpc_min_70,tpc_min_72, cwv_min):  
	today = datetime.datetime.now() #was just datetime.now, but import of datetime in players.py changed that....
	today = today.strftime("%B %d, %Y")

	results_list = []

	choice = input ("[T]PC or [C]WV? > ")

	if choice == 'T' or choice == 't':
		for player in player_list:
			if player.playing:
				results = [player.signup_name, player.h_i, player.handicap_tpc_70, player.handicap_tpc_70 - tpc_min_70] #, player.handicap_tpc_72, player.handicap_tpc_72 - tpc_min_72]
				results_list.append(results)

		results_list.sort()
		# results_list.insert(0,["   ", "   ",  "TPC HCP", "TPC-70", "TPC HCP", "TPC-72"])
		# results_list.insert(1,["Name", "Index","Par 70", "Strks", "Par 72", "Strks"])
		headers = ["\nName", "\nIndex", "TPC HCP\nWhites", "TPC\n Strokes"] #, "TPC HCP\n Par 72", "TPC-72\nStrokes" ]
		column_print_alignment = list(("right","right","right","right"))# , "right", "right"))
		course_info = f"TPC 70: CR = {tpc_rating_white_70} | SR = {tpc_slope_white_70} | Par = {tpc_hcp_70}"
		# course_info = course_info + f"TPC 72: CR = {tpc_rating_white_72} | SR = {tpc_slope_white_72} | Par = {tpc_hcp_72}"

	elif choice == 'C' or choice == 'c':
		for player in player_list:
			if player.playing:
				results = [player.signup_name, player.h_i, player.handicap_cwv_71, player.handicap_cwv_71-cwv_min]
				results_list.append(results)

		results_list.sort()
		# results_list.insert(0,["   ", "   ", "CWV HCP", "CWV"])
		# results_list.insert(1,["Name", "Index","Par 71", "Strokes"])
		headers = ["\nName", "\nIndex", "CWV HCP\nWhites", "CWV\n Strokes"] #, "TPC HCP\n Par 72", "TPC-72\nStrokes" ]		
		column_print_alignment = list(("right","right","right","right"))
		course_info = f"CWV: CR = {cwv_rating_white_71} | SR = {cwv_slope_white_71} | Par = {cwv_hcp_71}"

	else: print('Bad Choice')
	
	#Finish printout:
	print('-------------------------------------------------------')
	print(" \n Today's date:", today)
	print()
	print (tabulate(results_list, tablefmt='simple', colalign=column_print_alignment, headers=headers, floatfmt=".1f"))
	print ()
	print (course_info)
	print ('Course Handicap = (H.I. x SR / 113) + (CR - Par)')
	print ()
	# print('--------------------------------------------------------')
	for player in player_list:
		if player.playing:
			print (player.email)
	print("\n\n")
	#END-----------------PRINT OUT TABLE OF INDEXES / HANDICAPS / STROKES OFF LOW HANDICAP----------

# %%
def main():
	#Update the indexes of all players from the excel file
	get_indexes_from_xl_file()
	day_of_play = input("[M]onday, [W]ednesday, or [F]riday? >")
	update_player_status(day_of_play)

	#accumulate list of handicaps for sorting purposes
	tpc_list_70 = []
	tpc_list_72 = [] 
	cwv_list = [] 

	#TODO:  Complete the Smartsheet sign-up list to update player.playing

	for player in player_list:
		if player.playing:
			tpc_list_70.append(player.handicap_tpc_70)
			tpc_list_72.append(player.handicap_tpc_72)
			cwv_list.append(player.handicap_cwv_71)


	#determine lowest handicaps
	tpc_list_70.sort()
	tpc_min_70 = tpc_list_70[0] #lowest TPC70 handicap
	# print(f"TPC 70 Min: {tpc_min_70}")

	tpc_list_72.sort()
	tpc_min_72 = tpc_list_72[0] #lowest TPC72 handicap
	# print(f"TPC 72 Min: {tpc_min_72}")

	cwv_list.sort()
	cwv_min = cwv_list[0] #lowest CWV handicap
	# print(f"CWV Min: {cwv_min}")

	print_results_new(tpc_min_70,tpc_min_72, cwv_min)

# %% [markdown]
# Try to read / print out the spreadsheet using Pandas

# %%
def get_indexes_from_xl_using_pandas():
    df = pd.read_excel('Handicap Index Course Handicap Report.xlsx', sheet_name='Sheet1')
    print('Sheet Loaded')
    
    for ind in range(19):
        golfer_name = df['Golfer Name'][ind]
        h_i = (float(df['H.I.'][ind]))
        print(f"Golfer Name: {golfer_name}, \nHI: {h_i}")

    #Update handicap info in Player Class, set playing to no.
        for player in player_list:
#             print(f"Entering player list with GN: {golfer_name}, PN: {player.ghin_name}")
            if golfer_name == player.ghin_name:
                print(f"Processing: {golfer_name}")
                player.h_i = h_i
                player.class_tpc_white_70()
                player.class_tpc_white_72()
                player.class_cwv_white_71()
                player.playing = False

# %%
def main2():
    #Update the indexes of all players from the excel file
	get_indexes_from_xl_using_pandas()
	day_of_play = input("[M]onday, [W]ednesday, or [F]riday? >")
	update_player_status(day_of_play)

	#accumulate list of handicaps for sorting purposes
	tpc_list_70 = []
	tpc_list_72 = [] 
	cwv_list = [] 

	#TODO:  Complete the Smartsheet sign-up list to update player.playing

	for player in player_list:
		if player.playing:
			tpc_list_70.append(player.handicap_tpc_70)
			tpc_list_72.append(player.handicap_tpc_72)
			cwv_list.append(player.handicap_cwv_71)


	#determine lowest handicaps
	tpc_list_70.sort()
	tpc_min_70 = tpc_list_70[0] #lowest TPC70 handicap
	# print(f"TPC 70 Min: {tpc_min_70}")

	tpc_list_72.sort()
	tpc_min_72 = tpc_list_72[0] #lowest TPC72 handicap
	# print(f"TPC 72 Min: {tpc_min_72}")

	cwv_list.sort()
	cwv_min = cwv_list[0] #lowest CWV handicap
	# print(f"CWV Min: {cwv_min}")

	print_results_new(tpc_min_70,tpc_min_72, cwv_min)

# %%
main2()
# Out:
# Sheet Loaded
# Golfer Name: Reid Baker,
# HI: 11.4
# Entering player list with GN: Reid Baker, PN: Al Vela
# Entering player list with GN: Reid Baker, PN: Rick Besse
# Entering player list with GN: Reid Baker, PN: Bill Barnard
# Entering player list with GN: Reid Baker, PN: Bill  Strand
# Entering player list with GN: Reid Baker, PN: Bob Heard
# Entering player list with GN: Reid Baker, PN: Curt Fitzgerald
# Entering player list with GN: Reid Baker, PN: Dan Stewart
# Entering player list with GN: Reid Baker, PN: Doug Williams
# Entering player list with GN: Reid Baker, PN: Frank Broyles
# Entering player list with GN: Reid Baker, PN: Richard Humphrey
# Entering player list with GN: Reid Baker, PN: Jack Carroll
# Entering player list with GN: Reid Baker, PN: Jim Sido
# Entering player list with GN: Reid Baker, PN: Jimmy Wickham
# Entering player list with GN: Reid Baker, PN: Kent Fannon
# Entering player list with GN: Reid Baker, PN: Larry Traub
# Entering player list with GN: Reid Baker, PN: Reid Baker
# Processing: Reid Baker
# Entering player list with GN: Reid Baker, PN: Rocky Duron
# Entering player list with GN: Reid Baker, PN: Rick Baumgarth
# Entering player list with GN: Reid Baker, PN: Will Davis
# Golfer Name: Bill Barnard,
# HI: 16.5
# Entering player list with GN: Bill Barnard, PN: Al Vela
# Entering player list with GN: Bill Barnard, PN: Rick Besse
# Entering player list with GN: Bill Barnard, PN: Bill Barnard
# Processing: Bill Barnard
# Entering player list with GN: Bill Barnard, PN: Bill  Strand
# Entering player list with GN: Bill Barnard, PN: Bob Heard
# Entering player list with GN: Bill Barnard, PN: Curt Fitzgerald
# Entering player list with GN: Bill Barnard, PN: Dan Stewart
# Entering player list with GN: Bill Barnard, PN: Doug Williams
# Entering player list with GN: Bill Barnard, PN: Frank Broyles
# Entering player list with GN: Bill Barnard, PN: Richard Humphrey
# Entering player list with GN: Bill Barnard, PN: Jack Carroll
# Entering player list with GN: Bill Barnard, PN: Jim Sido
# Entering player list with GN: Bill Barnard, PN: Jimmy Wickham
# Entering player list with GN: Bill Barnard, PN: Kent Fannon
# Entering player list with GN: Bill Barnard, PN: Larry Traub
# Entering player list with GN: Bill Barnard, PN: Reid Baker
# Entering player list with GN: Bill Barnard, PN: Rocky Duron
# Entering player list with GN: Bill Barnard, PN: Rick Baumgarth
# Entering player list with GN: Bill Barnard, PN: Will Davis
# Golfer Name: Rick Baumgarth,
# HI: 11.4
# Entering player list with GN: Rick Baumgarth, PN: Al Vela
# Entering player list with GN: Rick Baumgarth, PN: Rick Besse
# Entering player list with GN: Rick Baumgarth, PN: Bill Barnard
# Entering player list with GN: Rick Baumgarth, PN: Bill  Strand
# Entering player list with GN: Rick Baumgarth, PN: Bob Heard
# Entering player list with GN: Rick Baumgarth, PN: Curt Fitzgerald
# Entering player list with GN: Rick Baumgarth, PN: Dan Stewart
# Entering player list with GN: Rick Baumgarth, PN: Doug Williams
# Entering player list with GN: Rick Baumgarth, PN: Frank Broyles
# Entering player list with GN: Rick Baumgarth, PN: Richard Humphrey
# Entering player list with GN: Rick Baumgarth, PN: Jack Carroll
# Entering player list with GN: Rick Baumgarth, PN: Jim Sido
# Entering player list with GN: Rick Baumgarth, PN: Jimmy Wickham
# Entering player list with GN: Rick Baumgarth, PN: Kent Fannon
# Entering player list with GN: Rick Baumgarth, PN: Larry Traub
# Entering player list with GN: Rick Baumgarth, PN: Reid Baker
# Entering player list with GN: Rick Baumgarth, PN: Rocky Duron
# Entering player list with GN: Rick Baumgarth, PN: Rick Baumgarth
# Processing: Rick Baumgarth
# Entering player list with GN: Rick Baumgarth, PN: Will Davis
# Golfer Name: Rick Besse,
# HI: 16.1
# Entering player list with GN: Rick Besse, PN: Al Vela
# Entering player list with GN: Rick Besse, PN: Rick Besse
# Processing: Rick Besse
# Entering player list with GN: Rick Besse, PN: Bill Barnard
# Entering player list with GN: Rick Besse, PN: Bill  Strand
# Entering player list with GN: Rick Besse, PN: Bob Heard
# Entering player list with GN: Rick Besse, PN: Curt Fitzgerald
# Entering player list with GN: Rick Besse, PN: Dan Stewart
# Entering player list with GN: Rick Besse, PN: Doug Williams
# Entering player list with GN: Rick Besse, PN: Frank Broyles
# Entering player list with GN: Rick Besse, PN: Richard Humphrey
# Entering player list with GN: Rick Besse, PN: Jack Carroll
# Entering player list with GN: Rick Besse, PN: Jim Sido
# Entering player list with GN: Rick Besse, PN: Jimmy Wickham
# Entering player list with GN: Rick Besse, PN: Kent Fannon
# Entering player list with GN: Rick Besse, PN: Larry Traub
# Entering player list with GN: Rick Besse, PN: Reid Baker
# Entering player list with GN: Rick Besse, PN: Rocky Duron
# Entering player list with GN: Rick Besse, PN: Rick Baumgarth
# Entering player list with GN: Rick Besse, PN: Will Davis
# Golfer Name: Frank Broyles,
# HI: 16.2
# Entering player list with GN: Frank Broyles, PN: Al Vela
# Entering player list with GN: Frank Broyles, PN: Rick Besse
# Entering player list with GN: Frank Broyles, PN: Bill Barnard
# Entering player list with GN: Frank Broyles, PN: Bill  Strand
# Entering player list with GN: Frank Broyles, PN: Bob Heard
# Entering player list with GN: Frank Broyles, PN: Curt Fitzgerald
# Entering player list with GN: Frank Broyles, PN: Dan Stewart
# Entering player list with GN: Frank Broyles, PN: Doug Williams
# Entering player list with GN: Frank Broyles, PN: Frank Broyles
# Processing: Frank Broyles
# Entering player list with GN: Frank Broyles, PN: Richard Humphrey
# Entering player list with GN: Frank Broyles, PN: Jack Carroll
# Entering player list with GN: Frank Broyles, PN: Jim Sido
# Entering player list with GN: Frank Broyles, PN: Jimmy Wickham
# Entering player list with GN: Frank Broyles, PN: Kent Fannon
# Entering player list with GN: Frank Broyles, PN: Larry Traub
# Entering player list with GN: Frank Broyles, PN: Reid Baker
# Entering player list with GN: Frank Broyles, PN: Rocky Duron
# Entering player list with GN: Frank Broyles, PN: Rick Baumgarth
# Entering player list with GN: Frank Broyles, PN: Will Davis
# Golfer Name: Jack Carroll,
# HI: 10.0
# Entering player list with GN: Jack Carroll, PN: Al Vela
# Entering player list with GN: Jack Carroll, PN: Rick Besse
# Entering player list with GN: Jack Carroll, PN: Bill Barnard
# Entering player list with GN: Jack Carroll, PN: Bill  Strand
# Entering player list with GN: Jack Carroll, PN: Bob Heard
# Entering player list with GN: Jack Carroll, PN: Curt Fitzgerald
# Entering player list with GN: Jack Carroll, PN: Dan Stewart
# Entering player list with GN: Jack Carroll, PN: Doug Williams
# Entering player list with GN: Jack Carroll, PN: Frank Broyles
# Entering player list with GN: Jack Carroll, PN: Richard Humphrey
# Entering player list with GN: Jack Carroll, PN: Jack Carroll
# Processing: Jack Carroll
# Entering player list with GN: Jack Carroll, PN: Jim Sido
# Entering player list with GN: Jack Carroll, PN: Jimmy Wickham
# Entering player list with GN: Jack Carroll, PN: Kent Fannon
# Entering player list with GN: Jack Carroll, PN: Larry Traub
# Entering player list with GN: Jack Carroll, PN: Reid Baker
# Entering player list with GN: Jack Carroll, PN: Rocky Duron
# Entering player list with GN: Jack Carroll, PN: Rick Baumgarth
# Entering player list with GN: Jack Carroll, PN: Will Davis
# Golfer Name: Will Davis,
# HI: 15.6
# Entering player list with GN: Will Davis, PN: Al Vela
# Entering player list with GN: Will Davis, PN: Rick Besse
# Entering player list with GN: Will Davis, PN: Bill Barnard
# Entering player list with GN: Will Davis, PN: Bill  Strand
# Entering player list with GN: Will Davis, PN: Bob Heard
# Entering player list with GN: Will Davis, PN: Curt Fitzgerald
# Entering player list with GN: Will Davis, PN: Dan Stewart
# Entering player list with GN: Will Davis, PN: Doug Williams
# Entering player list with GN: Will Davis, PN: Frank Broyles
# Entering player list with GN: Will Davis, PN: Richard Humphrey
# Entering player list with GN: Will Davis, PN: Jack Carroll
# Entering player list with GN: Will Davis, PN: Jim Sido
# Entering player list with GN: Will Davis, PN: Jimmy Wickham
# Entering player list with GN: Will Davis, PN: Kent Fannon
# Entering player list with GN: Will Davis, PN: Larry Traub
# Entering player list with GN: Will Davis, PN: Reid Baker
# Entering player list with GN: Will Davis, PN: Rocky Duron
# Entering player list with GN: Will Davis, PN: Rick Baumgarth
# Entering player list with GN: Will Davis, PN: Will Davis
# Processing: Will Davis
# Golfer Name: Rocky Duron,
# HI: 16.2
# Entering player list with GN: Rocky Duron, PN: Al Vela
# Entering player list with GN: Rocky Duron, PN: Rick Besse
# Entering player list with GN: Rocky Duron, PN: Bill Barnard
# Entering player list with GN: Rocky Duron, PN: Bill  Strand
# Entering player list with GN: Rocky Duron, PN: Bob Heard
# Entering player list with GN: Rocky Duron, PN: Curt Fitzgerald
# Entering player list with GN: Rocky Duron, PN: Dan Stewart
# Entering player list with GN: Rocky Duron, PN: Doug Williams
# Entering player list with GN: Rocky Duron, PN: Frank Broyles
# Entering player list with GN: Rocky Duron, PN: Richard Humphrey
# Entering player list with GN: Rocky Duron, PN: Jack Carroll
# Entering player list with GN: Rocky Duron, PN: Jim Sido
# Entering player list with GN: Rocky Duron, PN: Jimmy Wickham
# Entering player list with GN: Rocky Duron, PN: Kent Fannon
# Entering player list with GN: Rocky Duron, PN: Larry Traub
# Entering player list with GN: Rocky Duron, PN: Reid Baker
# Entering player list with GN: Rocky Duron, PN: Rocky Duron
# Processing: Rocky Duron
# Entering player list with GN: Rocky Duron, PN: Rick Baumgarth
# Entering player list with GN: Rocky Duron, PN: Will Davis
# Golfer Name: Kent Fannon,
# HI: 15.3
# Entering player list with GN: Kent Fannon, PN: Al Vela
# Entering player list with GN: Kent Fannon, PN: Rick Besse
# Entering player list with GN: Kent Fannon, PN: Bill Barnard
# Entering player list with GN: Kent Fannon, PN: Bill  Strand
# Entering player list with GN: Kent Fannon, PN: Bob Heard
# Entering player list with GN: Kent Fannon, PN: Curt Fitzgerald
# Entering player list with GN: Kent Fannon, PN: Dan Stewart
# Entering player list with GN: Kent Fannon, PN: Doug Williams
# Entering player list with GN: Kent Fannon, PN: Frank Broyles
# Entering player list with GN: Kent Fannon, PN: Richard Humphrey
# Entering player list with GN: Kent Fannon, PN: Jack Carroll
# Entering player list with GN: Kent Fannon, PN: Jim Sido
# Entering player list with GN: Kent Fannon, PN: Jimmy Wickham
# Entering player list with GN: Kent Fannon, PN: Kent Fannon
# Processing: Kent Fannon
# Entering player list with GN: Kent Fannon, PN: Larry Traub
# Entering player list with GN: Kent Fannon, PN: Reid Baker
# Entering player list with GN: Kent Fannon, PN: Rocky Duron
# Entering player list with GN: Kent Fannon, PN: Rick Baumgarth
# Entering player list with GN: Kent Fannon, PN: Will Davis
# Golfer Name: Curt Fitzgerald,
# HI: 18.2
# Entering player list with GN: Curt Fitzgerald, PN: Al Vela
# Entering player list with GN: Curt Fitzgerald, PN: Rick Besse
# Entering player list with GN: Curt Fitzgerald, PN: Bill Barnard
# Entering player list with GN: Curt Fitzgerald, PN: Bill  Strand
# Entering player list with GN: Curt Fitzgerald, PN: Bob Heard
# Entering player list with GN: Curt Fitzgerald, PN: Curt Fitzgerald
# Processing: Curt Fitzgerald
# Entering player list with GN: Curt Fitzgerald, PN: Dan Stewart
# Entering player list with GN: Curt Fitzgerald, PN: Doug Williams
# Entering player list with GN: Curt Fitzgerald, PN: Frank Broyles
# Entering player list with GN: Curt Fitzgerald, PN: Richard Humphrey
# Entering player list with GN: Curt Fitzgerald, PN: Jack Carroll
# Entering player list with GN: Curt Fitzgerald, PN: Jim Sido
# Entering player list with GN: Curt Fitzgerald, PN: Jimmy Wickham
# Entering player list with GN: Curt Fitzgerald, PN: Kent Fannon
# Entering player list with GN: Curt Fitzgerald, PN: Larry Traub
# Entering player list with GN: Curt Fitzgerald, PN: Reid Baker
# Entering player list with GN: Curt Fitzgerald, PN: Rocky Duron
# Entering player list with GN: Curt Fitzgerald, PN: Rick Baumgarth
# Entering player list with GN: Curt Fitzgerald, PN: Will Davis
# Golfer Name: Bob Heard,
# HI: 7.0
# Entering player list with GN: Bob Heard, PN: Al Vela
# Entering player list with GN: Bob Heard, PN: Rick Besse
# Entering player list with GN: Bob Heard, PN: Bill Barnard
# Entering player list with GN: Bob Heard, PN: Bill  Strand
# Entering player list with GN: Bob Heard, PN: Bob Heard
# Processing: Bob Heard
# Entering player list with GN: Bob Heard, PN: Curt Fitzgerald
# Entering player list with GN: Bob Heard, PN: Dan Stewart
# Entering player list with GN: Bob Heard, PN: Doug Williams
# Entering player list with GN: Bob Heard, PN: Frank Broyles
# Entering player list with GN: Bob Heard, PN: Richard Humphrey
# Entering player list with GN: Bob Heard, PN: Jack Carroll
# Entering player list with GN: Bob Heard, PN: Jim Sido
# Entering player list with GN: Bob Heard, PN: Jimmy Wickham
# Entering player list with GN: Bob Heard, PN: Kent Fannon
# Entering player list with GN: Bob Heard, PN: Larry Traub
# Entering player list with GN: Bob Heard, PN: Reid Baker
# Entering player list with GN: Bob Heard, PN: Rocky Duron
# Entering player list with GN: Bob Heard, PN: Rick Baumgarth
# Entering player list with GN: Bob Heard, PN: Will Davis
# Golfer Name: Richard Humphrey,
# HI: 17.6
# Entering player list with GN: Richard Humphrey, PN: Al Vela
# Entering player list with GN: Richard Humphrey, PN: Rick Besse
# Entering player list with GN: Richard Humphrey, PN: Bill Barnard
# Entering player list with GN: Richard Humphrey, PN: Bill  Strand
# Entering player list with GN: Richard Humphrey, PN: Bob Heard
# Entering player list with GN: Richard Humphrey, PN: Curt Fitzgerald
# Entering player list with GN: Richard Humphrey, PN: Dan Stewart
# Entering player list with GN: Richard Humphrey, PN: Doug Williams
# Entering player list with GN: Richard Humphrey, PN: Frank Broyles
# Entering player list with GN: Richard Humphrey, PN: Richard Humphrey
# Processing: Richard Humphrey
# Entering player list with GN: Richard Humphrey, PN: Jack Carroll
# Entering player list with GN: Richard Humphrey, PN: Jim Sido
# Entering player list with GN: Richard Humphrey, PN: Jimmy Wickham
# Entering player list with GN: Richard Humphrey, PN: Kent Fannon
# Entering player list with GN: Richard Humphrey, PN: Larry Traub
# Entering player list with GN: Richard Humphrey, PN: Reid Baker
# Entering player list with GN: Richard Humphrey, PN: Rocky Duron
# Entering player list with GN: Richard Humphrey, PN: Rick Baumgarth
# Entering player list with GN: Richard Humphrey, PN: Will Davis
# Golfer Name: Jim Sido,
# HI: 11.3
# Entering player list with GN: Jim Sido, PN: Al Vela
# Entering player list with GN: Jim Sido, PN: Rick Besse
# Entering player list with GN: Jim Sido, PN: Bill Barnard
# Entering player list with GN: Jim Sido, PN: Bill  Strand
# Entering player list with GN: Jim Sido, PN: Bob Heard
# Entering player list with GN: Jim Sido, PN: Curt Fitzgerald
# Entering player list with GN: Jim Sido, PN: Dan Stewart
# Entering player list with GN: Jim Sido, PN: Doug Williams
# Entering player list with GN: Jim Sido, PN: Frank Broyles
# Entering player list with GN: Jim Sido, PN: Richard Humphrey
# Entering player list with GN: Jim Sido, PN: Jack Carroll
# Entering player list with GN: Jim Sido, PN: Jim Sido
# Processing: Jim Sido
# Entering player list with GN: Jim Sido, PN: Jimmy Wickham
# Entering player list with GN: Jim Sido, PN: Kent Fannon
# Entering player list with GN: Jim Sido, PN: Larry Traub
# Entering player list with GN: Jim Sido, PN: Reid Baker
# Entering player list with GN: Jim Sido, PN: Rocky Duron
# Entering player list with GN: Jim Sido, PN: Rick Baumgarth
# Entering player list with GN: Jim Sido, PN: Will Davis
# Golfer Name: Dan Stewart,
# HI: 13.5
# Entering player list with GN: Dan Stewart, PN: Al Vela
# Entering player list with GN: Dan Stewart, PN: Rick Besse
# Entering player list with GN: Dan Stewart, PN: Bill Barnard
# Entering player list with GN: Dan Stewart, PN: Bill  Strand
# Entering player list with GN: Dan Stewart, PN: Bob Heard
# Entering player list with GN: Dan Stewart, PN: Curt Fitzgerald
# Entering player list with GN: Dan Stewart, PN: Dan Stewart
# Processing: Dan Stewart
# Entering player list with GN: Dan Stewart, PN: Doug Williams
# Entering player list with GN: Dan Stewart, PN: Frank Broyles
# Entering player list with GN: Dan Stewart, PN: Richard Humphrey
# Entering player list with GN: Dan Stewart, PN: Jack Carroll
# Entering player list with GN: Dan Stewart, PN: Jim Sido
# Entering player list with GN: Dan Stewart, PN: Jimmy Wickham
# Entering player list with GN: Dan Stewart, PN: Kent Fannon
# Entering player list with GN: Dan Stewart, PN: Larry Traub
# Entering player list with GN: Dan Stewart, PN: Reid Baker
# Entering player list with GN: Dan Stewart, PN: Rocky Duron
# Entering player list with GN: Dan Stewart, PN: Rick Baumgarth
# Entering player list with GN: Dan Stewart, PN: Will Davis
# Golfer Name: Bill  Strand,
# HI: 11.2
# Entering player list with GN: Bill  Strand, PN: Al Vela
# Entering player list with GN: Bill  Strand, PN: Rick Besse
# Entering player list with GN: Bill  Strand, PN: Bill Barnard
# Entering player list with GN: Bill  Strand, PN: Bill  Strand
# Processing: Bill  Strand
# Entering player list with GN: Bill  Strand, PN: Bob Heard
# Entering player list with GN: Bill  Strand, PN: Curt Fitzgerald
# Entering player list with GN: Bill  Strand, PN: Dan Stewart
# Entering player list with GN: Bill  Strand, PN: Doug Williams
# Entering player list with GN: Bill  Strand, PN: Frank Broyles
# Entering player list with GN: Bill  Strand, PN: Richard Humphrey
# Entering player list with GN: Bill  Strand, PN: Jack Carroll
# Entering player list with GN: Bill  Strand, PN: Jim Sido
# Entering player list with GN: Bill  Strand, PN: Jimmy Wickham
# Entering player list with GN: Bill  Strand, PN: Kent Fannon
# Entering player list with GN: Bill  Strand, PN: Larry Traub
# Entering player list with GN: Bill  Strand, PN: Reid Baker
# Entering player list with GN: Bill  Strand, PN: Rocky Duron
# Entering player list with GN: Bill  Strand, PN: Rick Baumgarth
# Entering player list with GN: Bill  Strand, PN: Will Davis
# Golfer Name: Larry Traub,
# HI: 8.9
# Entering player list with GN: Larry Traub, PN: Al Vela
# Entering player list with GN: Larry Traub, PN: Rick Besse
# Entering player list with GN: Larry Traub, PN: Bill Barnard
# Entering player list with GN: Larry Traub, PN: Bill  Strand
# Entering player list with GN: Larry Traub, PN: Bob Heard
# Entering player list with GN: Larry Traub, PN: Curt Fitzgerald
# Entering player list with GN: Larry Traub, PN: Dan Stewart
# Entering player list with GN: Larry Traub, PN: Doug Williams
# Entering player list with GN: Larry Traub, PN: Frank Broyles
# Entering player list with GN: Larry Traub, PN: Richard Humphrey
# Entering player list with GN: Larry Traub, PN: Jack Carroll
# Entering player list with GN: Larry Traub, PN: Jim Sido
# Entering player list with GN: Larry Traub, PN: Jimmy Wickham
# Entering player list with GN: Larry Traub, PN: Kent Fannon
# Entering player list with GN: Larry Traub, PN: Larry Traub
# Processing: Larry Traub
# Entering player list with GN: Larry Traub, PN: Reid Baker
# Entering player list with GN: Larry Traub, PN: Rocky Duron
# Entering player list with GN: Larry Traub, PN: Rick Baumgarth
# Entering player list with GN: Larry Traub, PN: Will Davis
# Golfer Name: Al Vela,
# HI: 19.5
# Entering player list with GN: Al Vela, PN: Al Vela
# Processing: Al Vela
# Entering player list with GN: Al Vela, PN: Rick Besse
# Entering player list with GN: Al Vela, PN: Bill Barnard
# Entering player list with GN: Al Vela, PN: Bill  Strand
# Entering player list with GN: Al Vela, PN: Bob Heard
# Entering player list with GN: Al Vela, PN: Curt Fitzgerald
# Entering player list with GN: Al Vela, PN: Dan Stewart
# Entering player list with GN: Al Vela, PN: Doug Williams
# Entering player list with GN: Al Vela, PN: Frank Broyles
# Entering player list with GN: Al Vela, PN: Richard Humphrey
# Entering player list with GN: Al Vela, PN: Jack Carroll
# Entering player list with GN: Al Vela, PN: Jim Sido
# Entering player list with GN: Al Vela, PN: Jimmy Wickham
# Entering player list with GN: Al Vela, PN: Kent Fannon
# Entering player list with GN: Al Vela, PN: Larry Traub
# Entering player list with GN: Al Vela, PN: Reid Baker
# Entering player list with GN: Al Vela, PN: Rocky Duron
# Entering player list with GN: Al Vela, PN: Rick Baumgarth
# Entering player list with GN: Al Vela, PN: Will Davis
# Golfer Name: Jimmy Wickham,
# HI: 14.5
# Entering player list with GN: Jimmy Wickham, PN: Al Vela
# Entering player list with GN: Jimmy Wickham, PN: Rick Besse
# Entering player list with GN: Jimmy Wickham, PN: Bill Barnard
# Entering player list with GN: Jimmy Wickham, PN: Bill  Strand
# Entering player list with GN: Jimmy Wickham, PN: Bob Heard
# Entering player list with GN: Jimmy Wickham, PN: Curt Fitzgerald
# Entering player list with GN: Jimmy Wickham, PN: Dan Stewart
# Entering player list with GN: Jimmy Wickham, PN: Doug Williams
# Entering player list with GN: Jimmy Wickham, PN: Frank Broyles
# Entering player list with GN: Jimmy Wickham, PN: Richard Humphrey
# Entering player list with GN: Jimmy Wickham, PN: Jack Carroll
# Entering player list with GN: Jimmy Wickham, PN: Jim Sido
# Entering player list with GN: Jimmy Wickham, PN: Jimmy Wickham
# Processing: Jimmy Wickham
# Entering player list with GN: Jimmy Wickham, PN: Kent Fannon
# Entering player list with GN: Jimmy Wickham, PN: Larry Traub
# Entering player list with GN: Jimmy Wickham, PN: Reid Baker
# Entering player list with GN: Jimmy Wickham, PN: Rocky Duron
# Entering player list with GN: Jimmy Wickham, PN: Rick Baumgarth
# Entering player list with GN: Jimmy Wickham, PN: Will Davis
# Golfer Name: Doug Williams,
# HI: 19.2
# Entering player list with GN: Doug Williams, PN: Al Vela
# Entering player list with GN: Doug Williams, PN: Rick Besse
# Entering player list with GN: Doug Williams, PN: Bill Barnard
# Entering player list with GN: Doug Williams, PN: Bill  Strand
# Entering player list with GN: Doug Williams, PN: Bob Heard
# Entering player list with GN: Doug Williams, PN: Curt Fitzgerald
# Entering player list with GN: Doug Williams, PN: Dan Stewart
# Entering player list with GN: Doug Williams, PN: Doug Williams
# Processing: Doug Williams
# Entering player list with GN: Doug Williams, PN: Frank Broyles
# Entering player list with GN: Doug Williams, PN: Richard Humphrey
# Entering player list with GN: Doug Williams, PN: Jack Carroll
# Entering player list with GN: Doug Williams, PN: Jim Sido
# Entering player list with GN: Doug Williams, PN: Jimmy Wickham
# Entering player list with GN: Doug Williams, PN: Kent Fannon
# Entering player list with GN: Doug Williams, PN: Larry Traub
# Entering player list with GN: Doug Williams, PN: Reid Baker
# Entering player list with GN: Doug Williams, PN: Rocky Duron
# Entering player list with GN: Doug Williams, PN: Rick Baumgarth
# Entering player list with GN: Doug Williams, PN: Will Davis
# [M]onday, [W]ednesday, or [F]riday? >w
# [T]PC or [C]WV? > c
# -------------------------------------------------------
#
#  Today's date: March 17, 2020
#
#                     CWV HCP         CWV
#    Name    Index     Whites     Strokes
# -------  -------  ---------  ----------
#   Besse     16.1         17          11
# Bill B.     16.5         17          11
#     Bob      7.0          6           0
#    Curt     18.2         19          13
#     Dan     13.5         14           8
#    Doug     19.2         20          14
#    Hump     17.6         18          12
#    Jack     10.0         10           4
#    Kent     15.3         16          10
#    Reid     11.4         11           5
#   Trick     11.4         11           5
#    Will     15.6         16          10
#
# CWV: CR = 69.3 | SR = 128 | Par = 71
# Course Handicap = (H.I. x SR / 113) + (CR - Par)
#
# rick@rickbesse.com
# wbarnard96@aol.com
# bheard3321@gmail.com
# Cmfitzg@gmail.com
# danstewart01@icloud.com
# dougwilliams9@hotmail.com
# rcraighumphrey@msn.com
# JackLCarroll@Verizon.net
# kent.fannon@verizon.net
# reid.baker@sbcglobal.net
# rbaumgarth@aol.com
# vanhorn_davis@verizon.net
